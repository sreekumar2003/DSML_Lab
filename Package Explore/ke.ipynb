# %%
pip install keras
# Out:
# ...
#   Using cached keras-3.11.3-py3-none-any.whl.metadata (5.9 kB)
# ...
#   Using cached absl_py-2.3.1-py3-none-any.whl.metadata (3.3 kB)
# ...
#   Using cached rich-14.1.0-py3-none-any.whl.metadata (18 kB)
# ...
#   Using cached namex-0.1.0-py3-none-any.whl.metadata (322 bytes)
# ...
#   Using cached h5py-3.14.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (2.7 kB)
# ...
#   Using cached optree-0.17.0-cp310-cp310-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (33 kB)
# ...
#   Using cached ml_dtypes-0.5.3-cp310-cp310-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (8.9 kB)
# ...
#   Using cached markdown_it_py-4.0.0-py3-none-any.whl.metadata (7.3 kB)
# ...
#   Using cached mdurl-0.1.2-py3-none-any.whl.metadata (1.6 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 24.3 MB/s  0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.6/4.6 MB 14.3 MB/s  0:00:00 eta 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.9/4.9 MB 5.6 MB/s  0:00:00 eta 0:00:01
# ...
