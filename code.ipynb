# %% [markdown]
# heatmap
#
# sns.heatmap(df.corr(),annot=True)
# plt.show()

# %% [markdown]
# Confusion Matrix
#
# cm = ConfusionMatrixDisplay(ConfusionMatrix = cm,diplay_labeles=model.classes_)
# cm.plot

# %% [markdown]
# scaler = StandardScaler()
#
# x = df.drop(columns=['species'])
#
# scaler.fit_transform(x)

# %% [markdown]
# Scatter plot

# %% [markdown]
# label encoding
#
# label = LabelEncoder()
#
# df['furnishingstatus_en'] = label.fit_transform(df['furnishingstatus'])
