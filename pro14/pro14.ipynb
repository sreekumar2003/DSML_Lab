# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score,davies_bouldin_score
from sklearn.preprocessing import StandardScaler

# %%
df = pd.read_csv("Breast_Cancer.csv")

# %%
df.head()
# Out:
#          id diagnosis  ...  fractal_dimension_worst  Unnamed: 32
# 0    842302         M  ...                  0.11890          NaN
# 1    842517         M  ...                  0.08902          NaN
# 2  84300903         M  ...                  0.08758          NaN
# 3  84348301         M  ...                  0.17300          NaN
# 4  84358402         M  ...                  0.07678          NaN
#
# [5 rows x 33 columns]

# %%
df.isnull().sum()
# Out:
# id                           0
# diagnosis                    0
# radius_mean                  0
# texture_mean                 0
# perimeter_mean               0
# area_mean                    0
# smoothness_mean              0
# compactness_mean             0
# concavity_mean               0
# concave points_mean          0
# symmetry_mean                0
# fractal_dimension_mean       0
# radius_se                    0
# texture_se                   0
# perimeter_se                 0
# area_se                      0
# smoothness_se                0
# compactness_se               0
# concavity_se                 0
# concave points_se            0
# symmetry_se                  0
# fractal_dimension_se         0
# radius_worst                 0
# texture_worst                0
# perimeter_worst              0
# area_worst                   0
# smoothness_worst             0
# compactness_worst            0
# concavity_worst              0
# concave points_worst         0
# ...

# %%
x = df.drop(columns=['smoothness_mean','id','Unnamed: 32','diagnosis','fractal_dimension_worst','symmetry_se','smoothness_se','texture_se','fractal_dimension_mean','concavity_se','compactness_se','symmetry_mean','fractal_dimension_worst','symmetry_worst','smoothness_worst','texture_worst','concave points_se','texture_mean','compactness_mean','radius_se','perimeter_se','area_se','compactness_worst','concavity_worst'])
y= df['diagnosis']

# %%
df['diagnosis'] = df['diagnosis'].map({'M': 1, 'B': 0})
df.head()
# Out:
#          id  diagnosis  ...  fractal_dimension_worst  Unnamed: 32
# 0    842302          1  ...                  0.11890          NaN
# 1    842517          1  ...                  0.08902          NaN
# 2  84300903          1  ...                  0.08758          NaN
# 3  84348301          1  ...                  0.17300          NaN
# 4  84358402          1  ...                  0.07678          NaN
#
# [5 rows x 33 columns]

# %%
x_corr= df.corr()
plt.figure(figsize=(30,20))
sns.heatmap(x_corr,annot=True)
plt.show()

# %%
scaler = StandardScaler()
x_scaled= scaler.fit_transform(x)

# %%
model = KMeans(n_clusters=2,random_state=42)
model.fit(x_scaled)
# Out:
# KMeans(n_clusters=2, random_state=42)

# %%
cluster = model.predict(x_scaled)

# %%
x['Cluster'] = cluster

# %%
x['Cluster'].value_counts()
# Out:
# Cluster
# 1    413
# 0    156
# Name: count, dtype: int64

# %%
plt.figure(figsize=(20,15))
sns.scatterplot(x='radius_mean',y='concave points_worst',data= x,hue = 'Cluster')
plt.show()

# %%
ine = []
k = range(1,11)
for i in k:
    kmean = KMeans(n_clusters=i,random_state=42)
    kmean.fit(x_scaled)
    ine.append(kmean.inertia_)

# %%
plt.figure(figsize=(8,6))
plt.plot(k, ine, 'bo-')
plt.xlabel('Number of clusters (k)')
plt.ylabel('Inertia')
plt.title('Elbow Method for Optimal k')
plt.show()

# %%
ss = silhouette_score(x_scaled, cluster)
ds = davies_bouldin_score(x_scaled, cluster)
print(ss)
print(ds)
# Out:
# 0.5462114282343102
# 0.7100677256894821
