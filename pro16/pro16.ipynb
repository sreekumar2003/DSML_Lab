# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.cluster import KMeans
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score,confusion_matrix,ConfusionMatrixDisplay,classification_report

# %%
df = pd.read_csv("iris.csv")
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
x = df.drop(columns=['species'])
y = df['species']

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=42)

# %%
model = KMeans(n_clusters=3,random_state=42)
model.fit(x_train,y_train)
# Out:
# KMeans(n_clusters=3, random_state=42)

# %%
y_prede=model.predict([[5.1,3.6,1.5,0.3]])
print(y_prede[0])
# Out:
# 1
# /home/user/DSML Lab/.venv/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but KMeans was fitted with feature names
#   warnings.warn(

# %% [markdown]
# accura

# %%
y_pred = model.predict(x_test)
accuracy_score = accuracy_score(y_test,y_pred)
print(accuracy_score)
# Out:
# 0.0

# %%
df["species"].value_counts()
# Out:
# species
# setosa        50
# versicolor    50
# virginica     50
# Name: count, dtype: int64

# %%
df_encode= df.copy()
df_encode['species'] = df_encode['species'].map({"setosa":1,"versicolor":2,"virginica":3})

# %%
corr = df_encode.corr()
corr

sns.heatmap(corr,annot=True)
# Out:
# <Axes: >

# %%
color_map = {'setosa': 'red', 'versicolor': 'green', 'virginica': 'blue'}
colors = df['species'].map(color_map)
plt.scatter(df['petal_length'],df['petal_width'], c=colors)
plt.show()
