# %%
pip install scikit-learn
# Out:
# Requirement already satisfied: scikit-learn in d:\programming\mca lab sem 3\dsml\dsml_lab\.venv\lib\site-packages (1.7.2)
# Requirement already satisfied: numpy>=1.22.0 in d:\programming\mca lab sem 3\dsml\dsml_lab\.venv\lib\site-packages (from scikit-learn) (2.3.4)
# Requirement already satisfied: scipy>=1.8.0 in d:\programming\mca lab sem 3\dsml\dsml_lab\.venv\lib\site-packages (from scikit-learn) (1.16.2)
# Requirement already satisfied: joblib>=1.2.0 in d:\programming\mca lab sem 3\dsml\dsml_lab\.venv\lib\site-packages (from scikit-learn) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in d:\programming\mca lab sem 3\dsml\dsml_lab\.venv\lib\site-packages (from scikit-learn) (3.6.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
age = [1,2,3,4,5]
speed = [2,4,6,8,10]

x = np.array(age).reshape(-1,1)
y = np.array(speed)

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import accuracy_score

# %%
model = LinearRegression()
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=42)
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(x_test)
m = model.coef_[0]
c = model.intercept_
acc = accuracy_score(y_test, y_pred)

# %%
value = model.predict([[20],[30]])
print(value[0],value[1])
# Out:
# 40.0 60.0

# %%
print(acc)
print(m)
print(c)
# Out:
# 1.0
# 2.0
# 0.0

# %%
plt.figure(figsize=( 5,3))
plt.scatter(x,y)
plt.xlabel("age")
plt.ylabel("speed")
plt.title("Scatter plot")
plt.plot(x,model.predict(x),color='red')
plt.show()
